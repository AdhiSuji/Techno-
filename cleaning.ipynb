# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()#standard missing values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.replace(0,np.NaN,inplace=True)
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       NaN       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       NaN       3
# 5             6       NaN       3
# 6             7       NaN       1
# 7             8       NaN       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       NaN       3
# 13           14       NaN       3
# 14           15       NaN       3
# 15           16       1.0       2
# 16           17       NaN       3
# 17           18       1.0       2
# 18           19       NaN       3
# 19           20       1.0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0    1.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived       549
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp          608
# Parch          678
# Ticket           0
# Fare            15
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean=round(data["Survived"].mean(),2)
mean
# Out:
# 1.0

# %%
data['Survived'].fillna(mean,inplace=True)
data['Survived'].head(20)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# Name: Survived, dtype: float64

# %%
data['Age'].interpolate(inplace=True)
data['Age'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     54.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    31.0
# 18    31.0
# 19    35.0
# Name: Age, dtype: float64

# %%
data['Age'].bfill(inplace=True)
data['Age'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     54.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    31.0
# 18    31.0
# 19    35.0
# Name: Age, dtype: float64

# %%
data['SibSp'].ffill(inplace=True)
data['SibSp'].head(20)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     3.0
# 8     3.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    4.0
# 17    4.0
# 18    1.0
# 19    1.0
# Name: SibSp, dtype: float64

# %%
data['Parch'].fillna(3.0,inplace=True)
data['Parch'].head(20)
# Out:
# 0     3.0
# 1     3.0
# 2     3.0
# 3     3.0
# 4     3.0
# 5     3.0
# 6     3.0
# 7     1.0
# 8     2.0
# 9     2.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    5.0
# 14    5.0
# 15    5.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# Name: Parch, dtype: float64

# %%
mode=data['Cabin'].mode()
mode
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
mode=data['Cabin'].mode()[1]
mode
# Out:
# 'C23 C25 C27'

# %%
data['Cabin'].fillna(mode,inplace=True)
data['Cabin'].head(20)
# Out:
# 0     C23 C25 C27
# 1             C85
# 2     C23 C25 C27
# 3            C123
# 4     C23 C25 C27
# 5     C23 C25 C27
# 6             E46
# 7     C23 C25 C27
# 8     C23 C25 C27
# 9     C23 C25 C27
# 10             G6
# 11           C103
# 12    C23 C25 C27
# 13    C23 C25 C27
# 14    C23 C25 C27
# 15    C23 C25 C27
# 16    C23 C25 C27
# 17    C23 C25 C27
# 18    C23 C25 C27
# 19    C23 C25 C27
# Name: Cabin, dtype: object

# %%
data['Embarked'].bfill(inplace=True)
data['Embarked'].head(20)
# Out:
# 0     S
# 1     C
# 2     S
# 3     S
# 4     S
# 5     Q
# 6     S
# 7     S
# 8     S
# 9     C
# 10    S
# 11    S
# 12    S
# 13    S
# 14    S
# 15    S
# 16    Q
# 17    S
# 18    S
# 19    C
# Name: Embarked, dtype: object

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
